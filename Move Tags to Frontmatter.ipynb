# %% [markdown]
# # Move Tags to Frontmatter
# A script that does the the following:
# 1. Grabs all markdown files in the current directory and its subdirectories.
# 2. For each markdown file:
#    - Move all occurrences of tags in the body `#<Word>` to the front of the file as a YAML frontmatter `tags: <Word>` .
#
# ## Usage
# 1. Move this .ipynb file to the desired directory (all subdirectories will also be affected).
# 2. Run the whole notebook.

# %%
# !pip3 install python-frontmatter
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: python-frontmatter in /usr/local/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/site-packages (from python-frontmatter) (6.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# WARNING: There was an error checking the latest version of pip.

# %%
import frontmatter
import os

exclude_directories = ['./Template', './.trash/']
# Get the paths of all markdown files in the current directory and its subdirectories, excluding the directories in exclude_directories
all_markdown_files = [os.path.join(dirpath, f) for dirpath, dirnames, files in os.walk('.') for f in files if f.endswith('.md')]
# Filter out the files in exclude_directories from all_markdown_files
markdown_files = [file for file in all_markdown_files if not any(file.startswith(exclude_dir) for exclude_dir in exclude_directories)]
def get_markdown_files():
	return [file for file in all_markdown_files if not any(file.startswith(exclude_dir) for exclude_dir in exclude_directories)]

# %%
import re
"""
A function that takes the path of a markdown file as input and returns a list of tags in the file's content (below the frontmatter)

            Parameters:
                    path (str): A path to a markdown file

            Returns:
                    tags (list[str]): A list of tags in the file's content as a list of strings
"""
def get_inline_tags(path: str) -> list[str]:
        frontmatter_data = frontmatter.load(path)
        # Remove all content wrapped with double brackets [[]], single brackets [], and parentheses () since #<Word> in double brackets imply a link to a section of a document
        file_contents_not_in_parentheses = re.sub(r'\(.*?\)', '', frontmatter_data.content)
        file_contents_not_in_square_brackets = re.sub(r'\[.*?\]', '', file_contents_not_in_parentheses)
        # Chars allowed in tags are a-z, A-Z, 0-9, dash, and underscore (cannot start with a number)
        chars_allowed_in_tags = r'#([a-zA-Z/\-_][a-zA-Z0-9/\-_]*)'
        # Regex match all tags in the content of the markdown file
        tags = re.findall(chars_allowed_in_tags, file_contents_not_in_square_brackets)
        # Remove duplicates from the list of tags
        tags = list(set(tags))
        # Sort the list of tags alphabetically in descending order
        tags.sort(reverse=True)
        return tags

# %%
for file in markdown_files:
	inline_tags = get_inline_tags(file)
	if len(inline_tags) > 0:
		print(inline_tags)
		# Add the inline_tags to the frontmatter of the markdown file
		frontmatter_data = frontmatter.load(file)
		# If the frontmatter already has tags
		if 'tags' in frontmatter_data.metadata:
			# If the tags are a list, add the inline_tags to the existing tags
			if isinstance(frontmatter_data.metadata['tags'], list):
				frontmatter_data.metadata['tags'] += inline_tags
			# Else it is a string, and so we'll convert it to a list and add the inline_tags
			else:
				frontmatter_data.metadata['tags'] = [frontmatter_data.metadata['tags']] + inline_tags
		else:
			frontmatter_data.metadata['tags'] = inline_tags
			
		# Remove the inline_tags from the content of the markdown file
		for tag in inline_tags:
			frontmatter_data.content = frontmatter_data.content.replace(f"#{tag}", '')
		frontmatter.dump(frontmatter_data, file)
		print(f'Added tags to {file}')
	else:
		print(f'No inline tags found in {file}')

# %%
# Sort tags
for file in markdown_files:
	frontmatter_data = frontmatter.load(file)
	# If 'tags' exists in the frontmatter of the markdown file and is a list
	if frontmatter_data.metadata.get('tags') is not None and isinstance(frontmatter_data.metadata['tags'], list):
		# Sort and remove duplicates from the list of tags
		frontmatter_data.metadata['tags'].sort()
		frontmatter.dump(frontmatter_data, file)

# %%
# Set the 'date' field in the frontmatter of the markdown file to the date in the first  heading, if it exists
for file in markdown_files:
	frontmatter_data = frontmatter.load(file)
	content = frontmatter_data.content
	# If there is a # [[YYYY-MM-DD]] in the content of the markdown file
	if re.search(r'# \[\[\d{4}-\d{2}-\d{2}\]\]', content):
		# Get the date in the first heading
		date = re.search(r'# \[\[\d{4}-\d{2}-\d{2}\]\]', content).group(0)
		print(date)
		# Remove the date from the content of the markdown file
		content = content.replace(date, '# ', 1)
		# Set the 'date' field in the frontmatter of the markdown file to the date in the first heading
		frontmatter_data.metadata['date'] = date[4:-2]
		# Replace all spaces in [[]] with _ in regex
		content = re.sub(r'\[\[\s*(\S*)\s*\]\]', r'[[\1]]', content)


		frontmatter.dump(frontmatter_data, file)

# %%
# Move files tagged "Type/__" to the folder "Notes/__/{file_name}"
for file in markdown_files:
	# If the frontmatter of the markdown file has a 'Type/Youtube_Notes' in the 'tags' field
	frontmatter_data = frontmatter.load(file)
	if frontmatter_data.metadata.get('tags') is not None and 'Type/Book' in frontmatter_data.metadata['tags']:
		# Move the file in the folder 'Notes/Videos'
		file_name = os.path.basename(file)
		os.rename(file, f'Notes/Books/{file_name}')
		print(f'Moved {file} to Notes/Books')

# %%
# For file in "Notes/Books", grab all Wikilinks and move them into "Notes/Books" as well
for file in os.listdir('Notes/Books'):
	if file.endswith('.md'):
		frontmatter_data = frontmatter.load(f'Notes/Books/{file}')
		content = frontmatter_data.content
		# Match contents of wikilink, even if it has an alias
		wikilink_regex = r'\[\[(.*?)\]\]'
		# If there is a Wikilink in the content of the markdown file
		if re.search(r'\[\[.*?\]\]', content):
			# Get the Wikilink
			wikilink = re.search(r'\[\[.*?\]\]', content).group(0)

			# Move the Wikilink to the folder 'Notes/Books'
			os.rename(f'Notes/Books/{file}', f'Notes/Books/{wikilink[3:-2]}.md')
			print(f'Moved {wikilink[3:-2]} to Notes/Books')

# %%
# Get a list of all files with more than one tag beginning with "Type" (more than one Type)
def get_files_with_multiple_types(markdown_files):
	for file in markdown_files:
		frontmatter_data = frontmatter.load(file)
		# If 'tags' exists in the frontmatter of the markdown file and is a list
		if frontmatter_data.metadata.get('tags') is not None and isinstance(frontmatter_data.metadata['tags'], list):
			# Get list of tags that start with "Type"
			tags_starting_with_type = [tag for tag in frontmatter_data.metadata['tags'] if tag.startswith('Type')]
			# If tags has more than one tag that starts with "Type"
			if len(tags_starting_with_type) > 1:
				# Move the file in the folder '0. Note Has Multiple Types'
				file_name = os.path.basename(file)
				os.rename(file, f'0. Note Has Multiple Types/{file_name}')
				print(f'Moved {file} to 0. Note Has Multiple Types')
refreshMarkdownFiles()
get_files_with_multiple_types(markdown_files)
# Out:
# Moved ./0. Note Has Multiple Types/History Remembers Those Who Believe in the Future.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/Cathedral Effect.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/Do Not Be the Child Your Parents Wants. Be the Child You Would Want Your Own Child to Be..md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/I Would Like to Be My Child's Advisor.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/Why Keeping the Room Cool Helps Sleep.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/Why I Prefer Data Engineering Roles.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/Efficiency is Doing Things Right. Effectiveness is Doing the Right Things..md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/Bluebooking for Happiness.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/AVAs in the Palms, Bottom of Feet, and Upper Half of Face Allow Cooling and Allow Us to Massively Improve Recovery..md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/Normalize Following Up and Checking In On Slackers.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/Researching Vs. Explaining Strategies.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/The Biggest Risk is Not Taking Any.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/The Only Reason We Choose to Speak Other Languages is Power.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/2021-11-14 Most People Are More Prepared for Rejection Than Acceptance. Why Are You Preparing for Failure but Not Success.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/People Will Disappoint You, and That's Ok.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/Open Source Intelligence (OSINT).md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/Monotheist Religions Were More Violent Than Polytheist Religions.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/F-35 is Misunderstood and Actually a Great Aircraft.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/Baby Boomers Versus Gen Z.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/2022-06-20 Post About Diversity in Effective Altruism.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/To Be Interesting, Be Interested.md to 0. Note Has Multiple Types
# Moved ./0. Note Has Multiple Types/What We Do in Darkness is What Makes Us Shine in the Light.md to 0. Note Has Multiple Types

# %%
# For file in markdown_files, if the file has a f'Type/{source}' in the 'tags' field, remove the f'Type/{source}' tag and add a "source" field with the source
def remove_type_add_source(source):
	for file in get_markdown_files():
		frontmatter_data = frontmatter.load(file)
		if frontmatter_data.metadata.get('tags') is not None and f'Type/{source}' in frontmatter_data.metadata['tags']:
			frontmatter_data.metadata['source'] = source
			print(f'Added source {source} to {file}')
			frontmatter_data.metadata['tags'].remove(f'Type/{source}')
			frontmatter.dump(frontmatter_data, file)
			print(f'Removed source {source} from {file}')
remove_type_add_source('Derived')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/braden/Library/Mobile Documents/iCloud~md~obsidian/Documents/Mind Map/Move Tags to Frontmatter.ipynb Cell 11' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/Users/braden/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Mind%20Map/Move%20Tags%20to%20Frontmatter.ipynb#ch0000010?line=8'>9</a> 			frontmatter.dump(frontmatter_data, file)
#      <a href='vscode-notebook-cell:/Users/braden/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Mind%20Map/Move%20Tags%20to%20Frontmatter.ipynb#ch0000010?line=9'>10</a> 			print(f'Removed source {source} from {file}')
# ---> <a href='vscode-notebook-cell:/Users/braden/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Mind%20Map/Move%20Tags%20to%20Frontmatter.ipynb#ch0000010?line=10'>11</a> remove_type_add_source('Derived')
#
# /Users/braden/Library/Mobile Documents/iCloud~md~obsidian/Documents/Mind Map/Move Tags to Frontmatter.ipynb Cell 11' in remove_type_add_source(source)
#       <a href='vscode-notebook-cell:/Users/braden/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Mind%20Map/Move%20Tags%20to%20Frontmatter.ipynb#ch0000010?line=1'>2</a> def remove_type_add_source(source):
#       <a href='vscode-notebook-cell:/Users/braden/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Mind%20Map/Move%20Tags%20to%20Frontmatter.ipynb#ch0000010?line=2'>3</a> 	for file in get_markdown_files():
# ----> <a href='vscode-notebook-cell:/Users/braden/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Mind%20Map/Move%20Tags%20to%20Frontmatter.ipynb#ch0000010?line=3'>4</a> 		frontmatter_data = frontmatter.load(file)
#       <a href='vscode-notebook-cell:/Users/braden/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Mind%20Map/Move%20Tags%20to%20Frontmatter.ipynb#ch0000010?line=4'>5</a> 		if frontmatter_data.metadata.get('tags') is not None and f'Type/{source}' in frontmatter_data.metadata['tags']:
#       <a href='vscode-notebook-cell:/Users/braden/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Mind%20Map/Move%20Tags%20to%20Frontmatter.ipynb#ch0000010?line=5'>6</a> 			frontmatter_data.metadata['source'] = source
#
# File /usr/local/lib/python3.9/site-packages/frontmatter/__init__.py:146, in load(fd, encoding, handler, **defaults)
#     143     text = fd.read()
#     145 else:
# --> 146     with codecs.open(fd, "r", encoding) as f:
#     147         text = f.read()
#     149 handler = handler or detect_format(text, handlers)
#
# File /usr/local/Cellar/python@3.9/3.9.13/Frameworks/Python.framework/Versions/3.9/lib/python3.9/codecs.py:905, in open(filename, mode, encoding, errors, buffering)
#     901 if encoding is not None and \
#     902    'b' not in mode:
#     903     # Force opening of the file in binary mode
#     904     mode = mode + 'b'
# --> 905 file = builtins.open(filename, mode, buffering)
#     906 if encoding is None:
#     907     return file
#
# FileNotFoundError: [Errno 2] No such file or directory: './Journal/Personal Life/2022-02-09 Dinner with Aarya, Then Ahmed.md'

# %%
# For file in markdown_files, if the file has a source in the "source" field, remove the categories field and add a f'Type/{category}' in the 'tags' field
def turn_source_to_tag():
	for file in get_markdown_files():
		frontmatter_data = frontmatter.load(file)
		if frontmatter_data.metadata.get('source') is not None:
			source = frontmatter_data.metadata['source']
			if frontmatter_data.metadata.get('tags') is None:
				frontmatter_data.metadata['tags'] = []
			# If exists and it is a string
			if frontmatter_data.metadata.get('tags') is not None and isinstance(frontmatter_data.metadata['tags'], str):
				frontmatter_data.metadata['tags'] = [frontmatter_data.metadata['tags']]
			frontmatter_data.metadata['tags'].append(f"Type/{source}")
			print(f'Added source {source} to {file}')
			# Remove the 'source' field
			del frontmatter_data.metadata['source']
			frontmatter.dump(frontmatter_data, file)
			print(f'Removed source {source} from {file}')
turn_source_to_tag()
# Out:
# Added source Original to ./Cards/Quotes/My Job Isn't to Implement My Solutions. My Job is to Solve Your Problems..md
# Removed source Original from ./Cards/Quotes/My Job Isn't to Implement My Solutions. My Job is to Solve Your Problems..md
# Added source Derived to ./Cards/Quotes/"Give Feedforward, Not feedback.".md
# Removed source Derived from ./Cards/Quotes/"Give Feedforward, Not feedback.".md
# Added source Derived to ./Cards/Fun Facts/Mozart's widow destroyed 90% of his early drafts to reinforce the notion that he was a prodigy #Fun_Facts.md
# Removed source Derived from ./Cards/Fun Facts/Mozart's widow destroyed 90% of his early drafts to reinforce the notion that he was a prodigy #Fun_Facts.md
# Added source Derived to ./Cards/Fun Facts/Baker Miller Pink Reduces Agression in Men.md
# Removed source Derived from ./Cards/Fun Facts/Baker Miller Pink Reduces Agression in Men.md
# Added source Derived to ./Cards/Fun Facts/3 Laws of Thermodynamics.md
# Removed source Derived from ./Cards/Fun Facts/3 Laws of Thermodynamics.md
# Added source Derived to ./Cards/Fun Facts/Fun Facts.md
# Removed source Derived from ./Cards/Fun Facts/Fun Facts.md
# Added source Derived to ./Cards/Fun Facts/Agriculture Began 9500 BC.md
# Removed source Derived from ./Cards/Fun Facts/Agriculture Began 9500 BC.md
# Added source Derived to ./Cards/Fun Facts/Sensitizing Versus Tolerance Reaction (Why Exposure Causes Allergies versus Immunity).md
# Removed source Derived from ./Cards/Fun Facts/Sensitizing Versus Tolerance Reaction (Why Exposure Causes Allergies versus Immunity).md
# Added source Podcast to ./Cards/Fleeting Notes/Jocko Podcast.md
# Removed source Podcast from ./Cards/Fleeting Notes/Jocko Podcast.md
# Added source Derived to ./Cards/Fleeting Notes/Conservatism.md
# Removed source Derived from ./Cards/Fleeting Notes/Conservatism.md
# Added source Article to ./Cards/Fleeting Notes/Stanford's War on Social Life.md
# Removed source Article from ./Cards/Fleeting Notes/Stanford's War on Social Life.md
# Added source Derived to ./Cards/Fleeting Notes/Most Conflicts Start When One or Both Sides Miscalculate the Costs or Chances of Winning War.md
# Removed source Derived from ./Cards/Fleeting Notes/Most Conflicts Start When One or Both Sides Miscalculate the Costs or Chances of Winning War.md
# Added source Derived to ./Cards/Fleeting Notes/Iterative Approach (of Evolution).md
# Removed source Derived from ./Cards/Fleeting Notes/Iterative Approach (of Evolution).md
# Added source Derived to ./Cards/Fleeting Notes/2021-04-08 Message to Dante About Housing.md
# Removed source Derived from ./Cards/Fleeting Notes/2021-04-08 Message to Dante About Housing.md
# Added source Derived to ./Cards/Fleeting Notes/Power Law Distribution.md
# Removed source Derived from ./Cards/Fleeting Notes/Power Law Distribution.md
# Added source Book to ./Cards/Fleeting Notes/Talent is Overrated.md
# Removed source Book from ./Cards/Fleeting Notes/Talent is Overrated.md
# Added source Derived to ./Cards/Fleeting Notes/Black Vs. Brown Shoes Analogy.md
# Removed source Derived from ./Cards/Fleeting Notes/Black Vs. Brown Shoes Analogy.md
# Added source Derived to ./Cards/Fleeting Notes/ The top model for all classification regression problems is gradient boosters (and most likely what you'll be working with). .md
# Removed source Derived from ./Cards/Fleeting Notes/ The top model for all classification regression problems is gradient boosters (and most likely what you'll be working with). .md
# Added source Derived to ./Cards/Fleeting Notes/Good Altruists Don't Necessarily Care More. Instead, They Learn to act.md
# Removed source Derived from ./Cards/Fleeting Notes/Good Altruists Don't Necessarily Care More. Instead, They Learn to act.md
# Added source Derived to ./Cards/Fleeting Notes/Alignment.md
# Removed source Derived from ./Cards/Fleeting Notes/Alignment.md
# Added source Derived to ./Cards/Fleeting Notes/Our Care-O-Meters Are Broken.md
# Removed source Derived from ./Cards/Fleeting Notes/Our Care-O-Meters Are Broken.md
# Added source Derived to ./Cards/Fleeting Notes/Perceptron Algorithm.md
# Removed source Derived from ./Cards/Fleeting Notes/Perceptron Algorithm.md
# Added source Derived to ./Cards/Fleeting Notes/"Women Need to Feel Loved to Have Sex. Men Need to Have Sex to Feel loved…''.md
# Removed source Derived from ./Cards/Fleeting Notes/"Women Need to Feel Loved to Have Sex. Men Need to Have Sex to Feel loved…''.md
# Added source Derived to ./Cards/Fleeting Notes/"Content Doesn't Determine Our Happiness but Context".md
# Removed source Derived from ./Cards/Fleeting Notes/"Content Doesn't Determine Our Happiness but Context".md
# Added source Derived to ./Cards/Fleeting Notes/Binary Tree Traversal.md
# Removed source Derived from ./Cards/Fleeting Notes/Binary Tree Traversal.md
# Added source Derived to ./Cards/Fleeting Notes/Progressivism.md
# Removed source Derived from ./Cards/Fleeting Notes/Progressivism.md
# Added source Derived to ./Cards/Fleeting Notes/80-20 Rule.md
# Removed source Derived from ./Cards/Fleeting Notes/80-20 Rule.md
# Added source Derived to ./Cards/Fleeting Notes/"A Jack of All Trades is a Master of None, but Oftentimes Better Than a Master of One.".md
# Removed source Derived from ./Cards/Fleeting Notes/"A Jack of All Trades is a Master of None, but Oftentimes Better Than a Master of One.".md
# Added source Podcast to ./Cards/Fleeting Notes/333 - Excuses and Rationalizations Are Not Valid… And We Know That (Dan Cnossen).md
# Removed source Podcast from ./Cards/Fleeting Notes/333 - Excuses and Rationalizations Are Not Valid… And We Know That (Dan Cnossen).md
# Added source Derived to ./Cards/Fleeting Notes/Unsupervised Learning.md
# Removed source Derived from ./Cards/Fleeting Notes/Unsupervised Learning.md
# Added source Derived to ./Cards/Fleeting Notes/"My Father Was a Mulatto, My Grandfather Was a Negro, and My Great-grandfather a Monkey. You See, Sir, My Family Starts Where Yours Ends.".md
# Removed source Derived from ./Cards/Fleeting Notes/"My Father Was a Mulatto, My Grandfather Was a Negro, and My Great-grandfather a Monkey. You See, Sir, My Family Starts Where Yours Ends.".md
# Added source Derived to ./Cards/Fleeting Notes/Leibniz Vs. Lagrange Derivative.md
# Removed source Derived from ./Cards/Fleeting Notes/Leibniz Vs. Lagrange Derivative.md
# Added source Derived to ./Cards/Fleeting Notes/You Can't Actually Feel the Weight of the World. But Sometimes, You Can Catch a Glimpse.md
# Removed source Derived from ./Cards/Fleeting Notes/You Can't Actually Feel the Weight of the World. But Sometimes, You Can Catch a Glimpse.md
# Added source Article to ./Cards/Fleeting Notes/Boring Advice Repository.md
# Removed source Article from ./Cards/Fleeting Notes/Boring Advice Repository.md
# Added source Video to ./Cards/Fleeting Notes/Why China Sucks.md
# Removed source Video from ./Cards/Fleeting Notes/Why China Sucks.md
# Added source Derived to ./Cards/Permanent Notes/Courage Isn't About Being Fearless, It's About Being Able to Do the Right Thing Even if You're Afraid..md
# Removed source Derived from ./Cards/Permanent Notes/Courage Isn't About Being Fearless, It's About Being Able to Do the Right Thing Even if You're Afraid..md
# Added source Derived to ./Sources/Articles/On Caring.md
# Removed source Derived from ./Sources/Articles/On Caring.md
# Added source Derived to ./Sources/Articles/We Didn't Finish Risk Calculations Before Detonating Nuclear Weapons.md
# Removed source Derived from ./Sources/Articles/We Didn't Finish Risk Calculations Before Detonating Nuclear Weapons.md
# Added source Article to ./Sources/Articles/How Houston Moved 25,000 People From the Streets Into Homes of Their Own.md
# Removed source Article from ./Sources/Articles/How Houston Moved 25,000 People From the Streets Into Homes of Their Own.md
# Added source Book to ./Sources/Books/Automate the Boring Stuff with Python.md
# Removed source Book from ./Sources/Books/Automate the Boring Stuff with Python.md
# Added source Book to ./Sources/Books/Outliers.md
# Removed source Book from ./Sources/Books/Outliers.md
# Added source Book to ./Sources/Books/Never Split the Difference.md
# Removed source Book from ./Sources/Books/Never Split the Difference.md
# Added source Book to ./Sources/Books/101 Essays That Will Change the Way You Think.md
# Removed source Book from ./Sources/Books/101 Essays That Will Change the Way You Think.md
# Added source Book to ./Sources/Books/AI Superpowers.md
# Removed source Book from ./Sources/Books/AI Superpowers.md
# Added source Book to ./Sources/Books/Elements of Programming Interviews.md
# Removed source Book from ./Sources/Books/Elements of Programming Interviews.md
# Added source Book to ./Sources/Books/Never Eat Alone.md
# Removed source Book from ./Sources/Books/Never Eat Alone.md
# Added source Course to ./Sources/Courses/CPSC 201.md
# Removed source Course from ./Sources/Courses/CPSC 201.md
# Added source Derived to ./Sources/Courses/ML Safety Scholars Program/Density Estimation.md
# Removed source Derived from ./Sources/Courses/ML Safety Scholars Program/Density Estimation.md
# Added source Course to ./Sources/Courses/ML Safety Scholars Program/ML Safety Scholars Program.md
# Removed source Course from ./Sources/Courses/ML Safety Scholars Program/ML Safety Scholars Program.md
# Added source Derived to ./Sources/Courses/ML Safety Scholars Program/Classification.md
# Removed source Derived from ./Sources/Courses/ML Safety Scholars Program/Classification.md
# Added source Derived to ./Sources/Courses/ML Safety Scholars Program/Supervised Learning.md
# Removed source Derived from ./Sources/Courses/ML Safety Scholars Program/Supervised Learning.md
# Added source Derived to ./Sources/Courses/ML Safety Scholars Program/Loss Function.md
# Removed source Derived from ./Sources/Courses/ML Safety Scholars Program/Loss Function.md
# Added source Video to ./Sources/Videos/Why Shipping Container Homes Are Overrated.md
# Removed source Video from ./Sources/Videos/Why Shipping Container Homes Are Overrated.md
# Added source Video to ./Sources/Videos/Artificial Wombs.md
# Removed source Video from ./Sources/Videos/Artificial Wombs.md
# Added source Video to ./Sources/Videos/David Crystal - Will English Always Be the Global Language?.md
# Removed source Video from ./Sources/Videos/David Crystal - Will English Always Be the Global Language?.md
# Added source Video to ./Sources/Videos/We Need to Talk About A.I..md
# Removed source Video from ./Sources/Videos/We Need to Talk About A.I..md
# Added source Video to ./Sources/Videos/How to Make Youtube Videos - What to Buy and How to Use It!.md
# Removed source Video from ./Sources/Videos/How to Make Youtube Videos - What to Buy and How to Use It!.md
# Added source Video to ./Sources/Videos/I Was Almost a School Shooter - Aaron Stark.md
# Removed source Video from ./Sources/Videos/I Was Almost a School Shooter - Aaron Stark.md
# Added source Video to ./Sources/Videos/Palmer Luckey on Forbes.md
# Removed source Video from ./Sources/Videos/Palmer Luckey on Forbes.md
# Added source Video to ./Sources/Videos/How McDonald's Evolved From Boomers to Zoomers.md
# Removed source Video from ./Sources/Videos/How McDonald's Evolved From Boomers to Zoomers.md
# Added source Video to ./Sources/Videos/There is ZERO Bias in Machine Learning Models.md
# Removed source Video from ./Sources/Videos/There is ZERO Bias in Machine Learning Models.md
# Added source Video to ./Sources/Videos/The Truth About Space War.md
# Removed source Video from ./Sources/Videos/The Truth About Space War.md
# Added source Video to ./Sources/Videos/The Number of Sexless Men Has Tripled in 10 Years.md
# Removed source Video from ./Sources/Videos/The Number of Sexless Men Has Tripled in 10 Years.md
# Added source Video to ./Sources/Videos/Young Generations Are Now Poorer Than Their Parents And It's Changing Our Economies.md
# Removed source Video from ./Sources/Videos/Young Generations Are Now Poorer Than Their Parents And It's Changing Our Economies.md
# Added source Video to ./Sources/Videos/Set Realistic Expectations in Your Machine Learning Journey.md
# Removed source Video from ./Sources/Videos/Set Realistic Expectations in Your Machine Learning Journey.md
# Added source Meeting to ./Sources/Meetings + Discussions/2022-04-18 In Depth Fellowship.md
# Removed source Meeting from ./Sources/Meetings + Discussions/2022-04-18 In Depth Fellowship.md
# Added source Meetings to ./Sources/Meetings + Discussions/2021-11-06 Lunch and gratitude sharing with Carrie and Rosemary.md
# Removed source Meetings from ./Sources/Meetings + Discussions/2021-11-06 Lunch and gratitude sharing with Carrie and Rosemary.md
# Added source Meeting to ./Sources/Meetings + Discussions/2021-11-30 Discussion About Climate Change in YEA Fellowship.md
# Removed source Meeting from ./Sources/Meetings + Discussions/2021-11-30 Discussion About Climate Change in YEA Fellowship.md
# Added source Meetings to ./Sources/Meetings + Discussions/2021-11-04 Eating in Harvest, Fellowship, Eating in Morse and Talking to Katherine About App.md
# Removed source Meetings from ./Sources/Meetings + Discussions/2021-11-04 Eating in Harvest, Fellowship, Eating in Morse and Talking to Katherine About App.md
# Added source Meetings to ./Sources/Meetings + Discussions/2022-03-07 Intro Fellowship.md
# Removed source Meetings from ./Sources/Meetings + Discussions/2022-03-07 Intro Fellowship.md
# Added source Derived to ./0. Note Has Multiple Types/Cathedral Effect.md
# Removed source Derived from ./0. Note Has Multiple Types/Cathedral Effect.md
# Added source Video to ./0. Note Has Multiple Types/Why I Prefer Data Engineering Roles.md
# Removed source Video from ./0. Note Has Multiple Types/Why I Prefer Data Engineering Roles.md
# Added source Article to ./0. Note Has Multiple Types/Bluebooking for Happiness.md
# Removed source Article from ./0. Note Has Multiple Types/Bluebooking for Happiness.md
# Added source Video to ./0. Note Has Multiple Types/Open Source Intelligence (OSINT).md
# Removed source Video from ./0. Note Has Multiple Types/Open Source Intelligence (OSINT).md
# Added source Derived to ./0. Note Has Multiple Types/Monotheist Religions Were More Violent Than Polytheist Religions.md
# Removed source Derived from ./0. Note Has Multiple Types/Monotheist Religions Were More Violent Than Polytheist Religions.md
# Added source Derived to ./0. Note Has Multiple Types/F-35 is Misunderstood and Actually a Great Aircraft.md
# Removed source Derived from ./0. Note Has Multiple Types/F-35 is Misunderstood and Actually a Great Aircraft.md
# Added source Slack to ./0. Note Has Multiple Types/2022-06-20 Post About Diversity in Effective Altruism.md
# Removed source Slack from ./0. Note Has Multiple Types/2022-06-20 Post About Diversity in Effective Altruism.md
